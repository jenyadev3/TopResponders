# %% [markdown]
# <a href="https://colab.research.google.com/github/jenyadev3/TopResponders/blob/main/vkr_project_target_company.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Задача** - построить портрет клиента, склонного к позитивному реагированию на реклама

# %% [markdown]
# **Шаг 1. Загрузка данных**

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/dataset_target_company.csv")

# %% [markdown]
# *Просмотр данных*

# %%
df.info()

# %%
df.describe()

# %%
df.head()

# %%
df.tail()

# %% [markdown]
# Исходя из первичного просмотра было выявлено:
#
# *   фрейм содержит 15223 записей, 37 колонок
# *   во многих колонках недостает записей
#
#
# *   уже понятно, что есть аномальные значения
# *   какие типы данных нужно будет менять
#
#
#
#
# Пока данные не менялись, дальнейшая предобработка будет произведена в следующем этапе

# %% [markdown]
# **Шаг 2. Первичная обработка данных**

# %% [markdown]
# ***Скорректировать заголовки***

# %% [markdown]
# *Смена названий заголовков*

# %%
df.columns = new_columns = ['id','target','age','is_employed','is_pensioner','gender','childs','dependants','education','marital_status','industry',
               'job_title','org_type_state','org_type_capital','job_field','family_income','personal_income','reg_province','fact_address',
               'postal_province','tp_province','region','has_real_state','own_auto','rus_auto','has_house','has_cottage',"has_garage",'has_land',
               'credit','term','residence_duration','work_experience','number_of_payments','overdue_payments','max_of_amount','credit_date']

df.describe()
# Out:
#                  id        target           age   is_employed  is_pensioner  \
# count  1.522300e+04  15223.000000  15223.000000  15223.000000  15223.000000
# mean   6.540183e+07      0.119030     40.406096      0.909610      0.134468
# std    4.568181e+06      0.323835     11.601068      0.286748      0.341165
# min    5.991015e+07      0.000000     21.000000      0.000000      0.000000
# 25%    6.192092e+07      0.000000     30.000000      1.000000      0.000000
# 50%    6.437100e+07      0.000000     39.000000      1.000000      0.000000
# 75%    6.708802e+07      0.000000     50.000000      1.000000      0.000000
# max    7.529224e+07      1.000000     67.000000      1.000000      1.000000
#
#              gender        childs    dependants  personal_income  \
# count  15223.000000  15223.000000  15223.000000     15223.000000
# mean       0.654536      1.099389      0.645208     13853.836323
# std        0.475535      0.995411      0.812252      9015.467617
# ...

# %% [markdown]
# *Настройка отображения чисел (убрать экспоненциальную запись) для более компактного понятного вида*

# %%
pd.options.display.float_format = "{:.2f}".format
df.describe()
# Out:
#                id   target      age  is_employed  is_pensioner   gender  \
# count    15223.00 15223.00 15223.00     15223.00      15223.00 15223.00
# mean  65401830.70     0.12    40.41         0.91          0.13     0.65
# std    4568181.14     0.32    11.60         0.29          0.34     0.48
# min   59910150.00     0.00    21.00         0.00          0.00     0.00
# 25%   61920915.00     0.00    30.00         1.00          0.00     0.00
# 50%   64370996.00     0.00    39.00         1.00          0.00     1.00
# 75%   67088017.50     0.00    50.00         1.00          0.00     1.00
# max   75292242.00     1.00    67.00         1.00          1.00     1.00
#
#         childs  dependants  personal_income  has_real_state  ...  has_cottage  \
# count 15223.00    15223.00         15223.00        15223.00  ...     15223.00
# mean      1.10        0.65         13853.84            0.31  ...         0.01
# std       1.00        0.81          9015.47            0.46  ...         0.10
# ...

# %% [markdown]
# *Изменение регистра, пробелов*

# %%
df.columns = (
    df.columns
    .str.lower()
    .str.strip()
)

df.head()
# Out:
#          id  target  age  is_employed  is_pensioner  gender  childs  \
# 0  59910150       0   49            1             0       1       2
# 1  59910230       0   32            1             0       1       3
# 2  59910525       0   52            1             0       1       4
# 3  59910803       0   39            1             0       1       1
# 4  59911781       0   30            1             0       0       0
#
#    dependants            education  marital_status  ... has_garage has_land  \
# 0           1  Среднее специальное  Состою в браке  ...          0        0
# 1           3              Среднее  Состою в браке  ...          0        0
# 2           0     Неполное среднее  Состою в браке  ...          0        0
# 3           1               Высшее  Состою в браке  ...          0        0
# 4           0              Среднее  Состою в браке  ...          0        0
#
#     credit term residence_duration work_experience  number_of_payments  \
# ...

# %% [markdown]
# *Дубликаты*

# %%
dups_all_except_id = df.duplicated(subset=[col for col in df.columns if col !="id"])
dups_all_except_id
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15218    False
# 15219    False
# 15220    False
# 15221    False
# 15222    False
# Length: 15223, dtype: bool

# %% [markdown]
# *Аномальные значения*

# %% [markdown]
# Проверяю бинарные колонки,
# где значение 0/1 чтобы узнать вдруг там содержатся другие цифры

# %%
# список бинарных колонок
df.info()
binary_cols = ["gender","target","is_employed","is_pensioner","has_land",
               "has_garage","has_cottage","has_house","has_real_state","rus_auto"]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15223 entries, 0 to 15222
# Data columns (total 37 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  15223 non-null  int64
#  1   target              15223 non-null  int64
#  2   age                 15223 non-null  int64
#  3   is_employed         15223 non-null  int64
#  4   is_pensioner        15223 non-null  int64
#  5   gender              15223 non-null  int64
#  6   childs              15223 non-null  int64
#  7   dependants          15223 non-null  int64
#  8   education           15223 non-null  object
#  9   marital_status      15223 non-null  object
#  10  industry            13856 non-null  object
#  11  job_title           13856 non-null  object
#  12  org_type_state      13856 non-null  object
#  13  org_type_capital    13858 non-null  object
#  14  job_field           13856 non-null  object
# ...

# %%
for col in binary_cols:
  invalid = df[(df[col]>0)|(df[col]>1)]
  print(f"{col}:{len(invalid)} неправильных значений")
# Out:
# gender:9964 неправильных значений
# target:1812 неправильных значений
# is_employed:13847 неправильных значений
# is_pensioner:2047 неправильных значений
# has_land:665 неправильных значений
# has_garage:293 неправильных значений
# has_cottage:149 неправильных значений
# has_house:3283 неправильных значений
# has_real_state:4716 неправильных значений
# rus_auto:1126 неправильных значений

# %%
df["rus_auto"].unique()
# тоже самое проделано(вставляла другие названия колонок в скобки) чтобы убедитьс] что других значений кроме 0 и 1 нет
# Out:
#              id  target  age  is_employed  is_pensioner  gender  childs  \
# 0      59910150       0   49            1             0       1       2
# 1      59910230       0   32            1             0       1       3
# 2      59910525       0   52            1             0       1       4
# 3      59910803       0   39            1             0       1       1
# 4      59911781       0   30            1             0       0       0
# ...         ...     ...  ...          ...           ...     ...     ...
# 15218  75291424       0   25            1             0       0       1
# 15219  75291888       0   51            1             0       1       2
# 15220  75291923       0   22            1             0       1       1
# 15221  75291960       0   60            0             1       1       2
# 15222  75292242       0   37            1             0       0       2
#
#        dependants            education      marital_status  ... has_garage  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3167748380.py in <cell line: 0>()
# ----> 1 binary_cols.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %% [markdown]
#  Смотрю мин/макс возраст (аномальных нет)

# %%
df["age"].describe()
# Out:
# count   15223.00
# mean       40.41
# std        11.60
# min        21.00
# 25%        30.00
# 50%        39.00
# 75%        50.00
# max        67.00
# Name: age, dtype: float64

# %% [markdown]
# Возраст дробным не может быть, решила округлять их до ближайшего числа

# %%
df["age"] = df["age"].round().astype("Int64")
df["age"]
# Out:
# 0        49
# 1        32
# 2        52
# 3        39
# 4        30
#          ..
# 15218    25
# 15219    51
# 15220    22
# 15221    60
# 15222    37
# Name: age, Length: 15223, dtype: Int64
